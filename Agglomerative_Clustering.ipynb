# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv("pollution_india_2010.csv",na_values='Null')

# %%
data.head()
# Out:
#          City   NO2  PM10  SO2           State
# 0     Chitoor   9.0  39.0  4.0  Andhra Pradesh
# 1      Guntur  11.0  81.0  2.0  Andhra Pradesh
# 2    Hydrabad  24.0  79.0  5.0  Andhra Pradesh
# 3  Kothagudem  11.0  62.0  2.0  Andhra Pradesh
# 4     Kurnool   9.0  85.0  4.0  Andhra Pradesh

# %%
#data['State']=data['State'].apply(lambda x: x[:-4])

# %%
data
# Out:
#                City   NO2   PM10   SO2           State
# 0           Chitoor   9.0   39.0   4.0  Andhra Pradesh
# 1            Guntur  11.0   81.0   2.0  Andhra Pradesh
# 2          Hydrabad  24.0   79.0   5.0  Andhra Pradesh
# 3        Kothagudem  11.0   62.0   2.0  Andhra Pradesh
# 4           Kurnool   9.0   85.0   4.0  Andhra Pradesh
# 5          Nalgonda  23.0   85.0   5.0  Andhra Pradesh
# 6           Nellore  12.0   65.0   2.0  Andhra Pradesh
# 7        Patencheru  23.0   76.0  11.0  Andhra Pradesh
# 8        Ramagundam  12.0   68.0   4.0  Andhra Pradesh
# 9          Tirupati   9.0   37.0   4.0  Andhra Pradesh
# 10        Vijaywada  14.0   93.0   6.0  Andhra Pradesh
# 11         Warangal  10.0   52.0   4.0  Andhra Pradesh
# 12   Vishakhapatnam  16.0   71.0   7.0  Andhra Pradesh
# 13       Bongaigaon  15.0   58.0   6.0           Assam
# 14          Daranga  14.0   58.0   5.0           Assam
# 15        Dibrugarh  14.0   38.0   6.0           Assam
# ...

# %%
data.isnull().sum()
# Out:
# City     0
# NO2      4
# PM10     1
# SO2      5
# State    0
# dtype: int64

# %%
data.shape
# Out:
# (181, 5)

# %%
data=data.dropna()

# %%
data.shape
# Out:
# (175, 5)

# %%
data.dtypes
# Out:
# City      object
# NO2      float64
# PM10     float64
# SO2      float64
# State     object
# dtype: object

# %%
data.head()
# Out:
#          City   NO2  PM10  SO2           State
# 0     Chitoor   9.0  39.0  4.0  Andhra Pradesh
# 1      Guntur  11.0  81.0  2.0  Andhra Pradesh
# 2    Hydrabad  24.0  79.0  5.0  Andhra Pradesh
# 3  Kothagudem  11.0  62.0  2.0  Andhra Pradesh
# 4     Kurnool   9.0  85.0  4.0  Andhra Pradesh

# %%
data_pol=data.groupby('State',as_index=False)[['NO2','PM10','SO2']].agg(np.sum)

# %%
data_pol.head()
# Out:
#             State    NO2   PM10   SO2
# 0  Andhra Pradesh  183.0  893.0  60.0
# 1           Assam  177.0  834.0  74.0
# 2           Bihar   40.0  181.0   7.0
# 3      Chandigarh   16.0   92.0   2.0
# 4     Chattisgarh   86.0  502.0  37.0

# %%
data_pol=data_pol.drop('State',axis=1)

# %%
def scale(x):
    return (x-np.mean(x))/np.std(x)

# %%
data_scaled=data_pol.apply(scale,axis=0)

# %%
data_scaled=data_num.apply(scale,axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-11b748389c3f> in <module>
# ----> 1 data_scaled=data_num.apply(scale,axis=1)
#
# NameError: name 'data_num' is not defined

# %%
data_scaled.head()

# %%
from scipy.cluster.hierarchy import dendrogram,linkage

# %%
#data_scaled=np.array(data_scaled)

data_scaled=np.array(data_scaled)

# %%
data_scaled
# Out:
# array([[ 2.37136818e-01,  4.15498576e-01, -3.18492302e-03],
#        [ 1.98682199e-01,  3.16828477e-01,  1.81540612e-01],
#        [-6.79364937e-01, -7.75232111e-01, -7.02503021e-01],
#        [-8.33183414e-01, -9.24073447e-01, -7.68476426e-01],
#        [-3.84546191e-01, -2.38399877e-01, -3.06662588e-01],
#        [-8.20365207e-01, -1.01270930e+00, -7.02503021e-01],
#        [-8.20365207e-01, -1.01939880e+00, -7.02503021e-01],
#        [-5.83228390e-01, -6.41442146e-01, -7.28892383e-01],
#        [ 4.55046326e-01,  4.15498576e-01,  7.62106580e-01],
#        [ 1.28182064e-01, -3.93873043e-02,  5.90575726e-01],
#        [-5.31955564e-01, -2.08297135e-01, -2.93467907e-01],
#        [-2.62773231e-01, -4.94215517e-02, -5.30972167e-01],
#        [-8.39592517e-01, -8.85608832e-01, -7.02503021e-01],
#        [ 8.01137898e-01,  1.24834111e+00,  1.28989382e+00],
#        [-1.02545651e-01, -3.82224089e-01, -1.21937053e-01],
#        [-8.97274446e-02, -3.03622485e-01, -3.06662588e-01],
# ...

# %%
#Z=linkage(data_scaled,method="ward")


z=linkage(data_scaled,method="complete")

# %%
z
# Out:
# array([[5.00000000e+00, 6.00000000e+00, 6.68949825e-03, 2.00000000e+00],
#        [2.20000000e+01, 2.90000000e+01, 3.50169420e-02, 3.00000000e+00],
#        [1.20000000e+01, 2.00000000e+01, 6.30514064e-02, 2.00000000e+00],
#        [3.00000000e+00, 3.10000000e+01, 9.13548892e-02, 3.00000000e+00],
#        [1.90000000e+01, 3.00000000e+01, 1.02002775e-01, 4.00000000e+00],
#        [2.00000000e+00, 1.80000000e+01, 1.10816498e-01, 2.00000000e+00],
#        [4.00000000e+00, 1.00000000e+01, 1.51029130e-01, 2.00000000e+00],
#        [2.10000000e+01, 2.40000000e+01, 1.59553688e-01, 2.00000000e+00],
#        [1.40000000e+01, 2.50000000e+01, 1.84751680e-01, 2.00000000e+00],
#        [3.20000000e+01, 3.30000000e+01, 1.87260880e-01, 7.00000000e+00],
#        [7.00000000e+00, 3.40000000e+01, 2.08774890e-01, 3.00000000e+00],
#        [0.00000000e+00, 1.00000000e+00, 2.12927381e-01, 2.00000000e+00],
#        [1.50000000e+01, 3.70000000e+01, 2.38368256e-01, 3.00000000e+00],
# ...

# %%
fig,ax=plt.subplots(figsize=(15,20))
ax=dendrogram(z,orientation="right",labels=np.array(data['State']),leaf_rotation=30,leaf_font_size=16)
plt.tight_layout()
plt.show()
